# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# from IPython import display

import os, glob
from PIL import Image

import numpy as np

import torch
from torch import nn
import torch.nn.functional as F
import torchvision

device = torch.device('cpu')
if torch.cuda.is_available():
    device = torch.device('cuda')
print('GPU available:', device)
# Out:
# GPU available: cuda

# %%
from google.colab import drive
drive.mount('/content/drive')

data_prefix = '/content/drive/Shared drives/Drive compartilhado EA999/data_augmentation'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Dataset
#
# O conjunto de dados que vamos usar nesta atividade foi obtido de uma competição do Kaggle, [https://www.kaggle.com/c/dogs-vs-cats/data](https://www.kaggle.com/c/dogs-vs-cats/data). Neste exemplo, utilizaremos as primeiras 1000 imagens de gatos e cachorros como conjunto de treinamento, totalizando 2000 imagens. Para validação usamos as 400 imagens seguintes de cachorros e gatos. O nosso dataset está organizado da seguinte forma:
#
#     /data/catsdogs_fewsamples/
#         train/
#             dogs/
#                 dog.0.jpg
#                 dog.1.jpg
#                 ...
#                 dog.999.jpg
#             cats/
#                 cat.0.jpg
#                 cat.1.jpg
#                 ...
#                 cat.999.jpg
#         validation/
#             dogs/
#                 dog.1000.jpg
#                 dog.1001.jpg
#                 ...
#                 dog.1399.jpg
#             cats/
#                 cat.1000.jpg
#                 cat.1001.jpg
#                 ...
#                 cat.1399.jpg

# %% [markdown]
# O PyTorch oferece diversas ferramentas para carregar e pré-processar os dados de maneira bem simples.
#
# Neste caso, vamos usar a classe `ImageFolder` para carregar as imagens de gatos e cachorros do nosso conjunto de dados:

# %%
from torchvision.datasets import ImageFolder
from torchvision import transforms

rootdir = data_prefix + '/data/catsdogs_fewsamples'

dataset_train = ImageFolder(rootdir + '/train/', transform=transforms.ToTensor())
dataset_valid = ImageFolder(rootdir + '/validation/', transform=transforms.ToTensor())

print(dataset_train)
print()
print(dataset_valid)
print()
# Out:
# Dataset ImageFolder
#     Number of datapoints: 2000
#     Root location: /content/drive/Shared drives/Drive compartilhado EA999/data_augmentation/data/catsdogs_fewsamples/train/
#     StandardTransform
# Transform: ToTensor()
#
# Dataset ImageFolder
#     Number of datapoints: 800
#     Root location: /content/drive/Shared drives/Drive compartilhado EA999/data_augmentation/data/catsdogs_fewsamples/validation/
#     StandardTransform
# Transform: ToTensor()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Podemos verificar algumas amostras para testar o carregamento dos dados:

# %%
toPIL = transforms.ToPILImage()

image, label = dataset_train[1]
print(label)
toPIL(image)
# Out:
# 0
# <PIL.Image.Image image mode=RGB size=300x280 at 0x7FD5E89916A0>

# %% [markdown]
# ### EXERCÍCIO 1:
# Escreva uma classe customizada para carregar o dataset de imagens descrito acima retornando uma tupla com o primento elemento sendo a imagem convertida em array e o segundo elemento a classe, gato (0) ou cachorro (1).
# Inclua também uma transformação para converter as imagens em tensores.
#
# *Lembretes:*
# - *a sua classe deve herdar da classe Dataset do PyTorch*
# - *é preciso redefinir os métodos* `__len__` *e* `__getitem__`

# %%
# torchvision.transforms.ToTensor
# Convert a PIL Image or numpy.ndarray to tensor.

# torchvision.transforms.ToPILImage(mode=None)
# Convert a tensor or an ndarray to PIL Image.

# transform=transforms.ToTensor()

# %%
dataset_train_path = rootdir + '/train/'
dataset_valid_path = rootdir + '/validation/'
dataset_train_path
# Out:
# '/content/drive/Shared drives/Drive compartilhado EA999/data_augmentation/data/catsdogs_fewsamples/train/'

# %%
from torch.utils.data import Dataset
from PIL import Image
import os
pil2tensor = torchvision.transforms.ToTensor()

# %%
class CatsAndDogs(Dataset):
    def __init__(self, path, transform=None):
        super(CatsAndDogs, self).__init__()
        self.path = path
        self.classes = os.listdir(path)
        self.transform = transform

        # get number of classes
        N_classes = len(os.listdir(path))
        filenames = []
        dataset_files = []

        # loop for each class
        for i in range(N_classes):
            class_path = os.path.join(path, self.classes[i])     # joing path
            filenames.append(os.listdir(class_path))        # read all files for that class
            dataset_files += filenames[i]
        self.dataset_files = dataset_files

        # create target array
        dataset_target = np.zeros(len(dataset_files))
        class_path = os.path.join(path, self.classes[0])     # joing path
        #===============================================
        # ONLY WORKS FOR BINARY CLASSES
        dataset_target[len(os.listdir(class_path)):] = 1
        #===============================================
        
        self.target = dataset_target

    def __len__(self):
        return len(self.dataset_files)

    def __getitem__(self, index):
        #===============================================
        # ONLY WORKS FOR BINARY CLASSES
        if index < 1000:
            new_path = self.path + 'cats/'
        else:
            new_path = self.path + 'dogs/'
        #===============================================
        image = Image.open(new_path + self.dataset_files[index])
        array = image
#        array = np.array(image)
        if self.transform:
            array = self.transform(array)
        return array, int(self.target[index])

# %%
dataset_train = CatsAndDogs(dataset_train_path)
print(type(dataset_train[0][0]))
dataset_train = CatsAndDogs(dataset_train_path, transform=pil2tensor)
print(type(dataset_train[0][0]))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <class 'torch.Tensor'>

# %% [markdown]
# ### EXERCÍCIO 2:
#
# Escreva uma transformação para redimensionar as imagens para tamanhos de (224, 224) e a adicione ao seu dataset.
#
# *Dica:*
# - *Use a classe Compose do PyTorch para combinar as transformações redimensionamento e conversão para tensores*,  [torchvision.transforms.Compose](https://pytorch.org/docs/stable/torchvision/transforms.html#torchvision.transforms.Compose)

# %%
class Resize(object):
    def __init__(self, output_size):
        self.output_size = output_size
    def __call__(self, data):
        im = Image.Image()
        image = data.resize(self.output_size)
        return image

# %%
normalize = transforms.Normalize(
    mean=[0.485, 0.456, 0.406],
    std=[0.229, 0.224, 0.225])

# %%
resize_image = Resize(output_size=(224,224))
#-------------------------------------------------
transforms_list = [
    resize_image,
    pil2tensor,
    normalize,
]
#-------------------------------------------------
image_transform = torchvision.transforms.Compose(transforms_list)

# %%
dataset_train = CatsAndDogs(dataset_train_path, transform=pil2tensor)
print(dataset_train[0][0].shape)
toPIL(dataset_train[0][0])
# Out:
# torch.Size([3, 374, 500])
# <PIL.Image.Image image mode=RGB size=500x374 at 0x7FD5E71316A0>

# %%
dataset_train = CatsAndDogs(dataset_train_path, transform=image_transform)
print(dataset_train[0][0].shape)
toPIL(dataset_train[0][0])
# Out:
# torch.Size([3, 224, 224])
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FD5E71317B8>

# %%
dataset_train = ImageFolder(rootdir + '/train/', transform=image_transform)
dataset_valid = ImageFolder(rootdir + '/validation/', transform=image_transform)

# %% [markdown]
# ## DataLoader
# Podemos agora definir um DataLoader para facilitar a carregamento dos dados durante o treinamento:

# %%
from torch.utils.data import DataLoader

# %%
# DataLoader for training set
dl_train = DataLoader(
    dataset_train, 
    batch_size=10,
    #drop_last = True,
    shuffle=False)
#-------------------
# DataLoader for validation set
dl_val = DataLoader(
    dataset_valid, 
    batch_size=10,
    #drop_last = True,
    shuffle=False)

# %% [markdown]
# ### EXERCÍCIO 3:
# Crie um dataloader e teste o carregamento dos dados para um *batch_size* de 20 amostras.
#
# *Sugestão:*
# - *Use a ferramenta* `torch.utils.make_grid` *para visualizar as imagens*

# %%
#torchvision.utils.make_grid(imgs[:10])

# %% [markdown]
# ## Treinamento do Modelo

# %%
N_SAMPLES = len(dataset_train)
V_SAMPLES = len(dataset_valid)

# %% [markdown]
# ### ResNet18

# %%
# importing the model
import torchvision.models as models
resnet18 = models.resnet18(pretrained=True)
#-------------------
# freeze all weights
for param in resnet18.parameters():
    param.requires_grad = False
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/checkpoints/resnet18-5c106cde.pth
# HBox(children=(IntProgress(value=0, max=46827520), HTML(value='')))

# %% [markdown]
# ### Modifying ResNet's last layer

# %%
resnet18.fc = torch.nn.Identity(in_features=512, out_features=512)

# %% [markdown]
# ### Network predict

# %%
from torch.utils.data import TensorDataset

# %%
x = torch.zeros(N_SAMPLES, 512, dtype=torch.float32)
y = torch.zeros(N_SAMPLES, dtype=torch.int64)

# %%
# evaluation mode
resnet18.eval()
# create "new dataset"
for b_i, (b_x, b_y) in enumerate(dl_train):
    x[b_i*10:(b_i+1)*10,] = resnet18(b_x)
    y[b_i*10:(b_i+1)*10,] = b_y
    print(b_i, b_x.shape, b_y.shape, x[b_i*10:(b_i+1)*10,].shape, y[b_i*10:(b_i+1)*10,].shape)
# Out:
# 0 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 1 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 2 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 3 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 4 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 5 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 6 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 7 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 8 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 9 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 10 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 11 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 12 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 13 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 14 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 15 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 16 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 17 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 18 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 19 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 20 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 21 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 22 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 23 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 24 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 25 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 26 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 27 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 28 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 29 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 30 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 31 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 32 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 33 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 34 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 35 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 36 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 37 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 38 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 39 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 40 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 41 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 42 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 43 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 44 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 45 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 46 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 47 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 48 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 49 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 50 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 51 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 52 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 53 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 54 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 55 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 56 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 57 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 58 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 59 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 60 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 61 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 62 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 63 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 64 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 65 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 66 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 67 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 68 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 69 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 70 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 71 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 72 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 73 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 74 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 75 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 76 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 77 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 78 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 79 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 80 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 81 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 82 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 83 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 84 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 85 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 86 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 87 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 88 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 89 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 90 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 91 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 92 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 93 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 94 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 95 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 96 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 97 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 98 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 99 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 100 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 101 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 102 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 103 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 104 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 105 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 106 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 107 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 108 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 109 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 110 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 111 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 112 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 113 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 114 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 115 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 116 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 117 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 118 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 119 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 120 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 121 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 122 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 123 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 124 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 125 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 126 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 127 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 128 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 129 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 130 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 131 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 132 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 133 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 134 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 135 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 136 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 137 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 138 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 139 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 140 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 141 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 142 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 143 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 144 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 145 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 146 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 147 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 148 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 149 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 150 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 151 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 152 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 153 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 154 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 155 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 156 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 157 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 158 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 159 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 160 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 161 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 162 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 163 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 164 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 165 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 166 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 167 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 168 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 169 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 170 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 171 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 172 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 173 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 174 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 175 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 176 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 177 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 178 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 179 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 180 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 181 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 182 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 183 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 184 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 185 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 186 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 187 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 188 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 189 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 190 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 191 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 192 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 193 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 194 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 195 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 196 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 197 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 198 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 199 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])

# %%
xval = torch.zeros(V_SAMPLES, 512, dtype=torch.float32)
yval = torch.zeros(V_SAMPLES, dtype=torch.int64)

# %%
# evaluation mode
resnet18.eval()
# create "new dataset"
for b_i, (b_x, b_y) in enumerate(dl_val):
    xval[b_i*10:(b_i+1)*10,] = resnet18(b_x)
    yval[b_i*10:(b_i+1)*10,] = b_y
    print(b_i, b_x.shape, b_y.shape, xval[b_i*10:(b_i+1)*10,].shape, yval[b_i*10:(b_i+1)*10,].shape)
# Out:
# 0 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 1 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 2 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 3 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 4 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 5 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 6 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 7 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 8 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 9 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 10 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 11 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 12 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 13 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 14 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 15 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 16 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 17 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 18 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 19 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 20 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 21 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 22 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 23 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 24 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 25 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 26 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 27 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 28 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 29 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 30 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 31 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 32 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 33 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 34 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 35 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 36 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 37 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 38 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 39 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 40 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 41 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 42 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 43 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 44 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 45 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 46 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 47 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 48 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 49 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 50 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 51 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 52 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 53 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 54 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 55 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 56 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 57 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 58 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 59 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 60 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 61 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 62 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 63 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 64 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 65 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 66 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 67 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 68 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 69 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 70 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 71 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 72 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 73 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 74 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 75 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 76 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 77 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 78 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])
# 79 torch.Size([10, 3, 224, 224]) torch.Size([10]) torch.Size([10, 512]) torch.Size([10])

# %%
ds_transformed_train = TensorDataset(x, y)
ds_transformed_valid = TensorDataset(xval, yval)

# %%
# DataLoader for training set
dl_transformed_train = DataLoader(
    ds_transformed_train, 
    batch_size=100,
    #drop_last = True,
    shuffle=True)

# %%
# DataLoader for validation set
dl_transformed_val = DataLoader(
    ds_transformed_valid, 
    batch_size=100,
    #drop_last = True,
    shuffle=True)

# %% [markdown]
# ### Training only last layer

# %%
class FC(torch.nn.Module):
    def __init__(self):
        super(FC, self).__init__()
        self.fc = torch.nn.Linear(in_features=512, out_features=2)
    def forward(self, x):
        return self.fc(x)

# %%
model = FC()
# Training parameters
EPOCH = 100
LR = 0.001
loss_func = torch.nn.CrossEntropyLoss()
opt = torch.optim.SGD(model.parameters(), lr=LR)
# loss history
loss_his = []
loss_val_his = []

# %%
for epoch in range(EPOCH):
    print('epoch =', epoch, end='; ')
    #-------------------------------------------------
    # training
    model.train()
    zero_one_loss = 0.
    for b_i, (b_x, b_y) in enumerate(dl_transformed_train):   # for each training step
        y_logitos = model(b_x)
        loss = loss_func(y_logitos, b_y)
        opt.zero_grad()                 # clear gradients for next train
        loss.backward()                 # backpropagation, compute gradients
        opt.step()                      # apply gradients
        #-------------------
        y_pred = torch.argmax(y_logitos, dim=1)
        zero_one_loss += (b_y == y_pred).sum()
    acc_train = zero_one_loss / N_SAMPLES
    #-------------------------------------------------
    # validation
    model.eval()
    zero_one_loss_val = 0.
    for b_ival, (b_xval, b_yval) in enumerate(dl_transformed_val):
        y_logitos = model(b_xval)
        loss_val = loss_func(y_logitos, b_yval)
        yval_pred = torch.argmax(y_logitos, dim=1)
        zero_one_loss_val += (b_yval == yval_pred).sum()
    #-------------------------------------------------
    loss_his.append(loss.item())    # loss recoder
    loss_val_his.append(loss_val.item())    # loss recoder
    acc_val = zero_one_loss_val / len(ds_transformed_valid)
    #-------------------------------------------------
    print('loss_train = {0:.4f}'.format(loss_his[-1]), end='; ')
    print('loss_val = {0:.4f}'.format(loss_val_his[-1]), end='; ')
    print('acc_train = {0:.4f}'.format(acc_train), end='; ')
    print('acc_val = {0:.4f}'.format(acc_val), end='\n')
# Out:
# epoch = 0; loss_train = 0.4835; loss_val = 0.5019; acc_train = 0.8700; acc_val = 0.8300
# epoch = 1; loss_train = 0.3415; loss_val = 0.3681; acc_train = 0.9800; acc_val = 0.9162
# epoch = 2; loss_train = 0.3544; loss_val = 0.2582; acc_train = 0.8800; acc_val = 0.9475
# epoch = 3; loss_train = 0.3071; loss_val = 0.2331; acc_train = 0.8800; acc_val = 0.9563
# epoch = 4; loss_train = 0.2139; loss_val = 0.1923; acc_train = 0.9700; acc_val = 0.9675
# epoch = 5; loss_train = 0.2166; loss_val = 0.1677; acc_train = 0.9700; acc_val = 0.9712
# epoch = 6; loss_train = 0.2250; loss_val = 0.1814; acc_train = 0.9400; acc_val = 0.9725
# epoch = 7; loss_train = 0.1619; loss_val = 0.1496; acc_train = 0.9600; acc_val = 0.9750
# epoch = 8; loss_train = 0.1535; loss_val = 0.1447; acc_train = 0.9600; acc_val = 0.9737
# epoch = 9; loss_train = 0.1398; loss_val = 0.1240; acc_train = 0.9800; acc_val = 0.9737
# epoch = 10; loss_train = 0.1276; loss_val = 0.1245; acc_train = 0.9700; acc_val = 0.9737
# epoch = 11; loss_train = 0.1498; loss_val = 0.1021; acc_train = 0.9700; acc_val = 0.9762
# epoch = 12; loss_train = 0.1653; loss_val = 0.1290; acc_train = 0.9400; acc_val = 0.9750
# epoch = 13; loss_train = 0.1419; loss_val = 0.1320; acc_train = 0.9700; acc_val = 0.9762
# epoch = 14; loss_train = 0.1275; loss_val = 0.1200; acc_train = 0.9600; acc_val = 0.9762
# epoch = 15; loss_train = 0.1056; loss_val = 0.1094; acc_train = 0.9800; acc_val = 0.9762
# epoch = 16; loss_train = 0.0945; loss_val = 0.1075; acc_train = 0.9900; acc_val = 0.9775
# epoch = 17; loss_train = 0.1129; loss_val = 0.0726; acc_train = 0.9800; acc_val = 0.9787
# epoch = 18; loss_train = 0.1113; loss_val = 0.1345; acc_train = 0.9700; acc_val = 0.9787
# epoch = 19; loss_train = 0.1002; loss_val = 0.0671; acc_train = 0.9900; acc_val = 0.9787
# epoch = 20; loss_train = 0.0844; loss_val = 0.0973; acc_train = 0.9700; acc_val = 0.9800
# epoch = 21; loss_train = 0.0826; loss_val = 0.1161; acc_train = 0.9800; acc_val = 0.9800
# epoch = 22; loss_train = 0.1477; loss_val = 0.0835; acc_train = 0.9300; acc_val = 0.9800
# epoch = 23; loss_train = 0.1318; loss_val = 0.1158; acc_train = 0.9600; acc_val = 0.9812
# epoch = 24; loss_train = 0.1176; loss_val = 0.0840; acc_train = 0.9700; acc_val = 0.9800
# epoch = 25; loss_train = 0.1011; loss_val = 0.1019; acc_train = 0.9700; acc_val = 0.9812
# epoch = 26; loss_train = 0.0709; loss_val = 0.0805; acc_train = 0.9900; acc_val = 0.9812
# epoch = 27; loss_train = 0.0975; loss_val = 0.0914; acc_train = 0.9700; acc_val = 0.9825
# epoch = 28; loss_train = 0.0981; loss_val = 0.0954; acc_train = 0.9700; acc_val = 0.9825
# epoch = 29; loss_train = 0.1081; loss_val = 0.0913; acc_train = 0.9700; acc_val = 0.9825
# epoch = 30; loss_train = 0.1045; loss_val = 0.0753; acc_train = 0.9600; acc_val = 0.9825
# epoch = 31; loss_train = 0.0687; loss_val = 0.0676; acc_train = 1.0000; acc_val = 0.9825
# epoch = 32; loss_train = 0.0723; loss_val = 0.1097; acc_train = 0.9800; acc_val = 0.9825
# epoch = 33; loss_train = 0.0808; loss_val = 0.0685; acc_train = 0.9700; acc_val = 0.9825
# epoch = 34; loss_train = 0.0724; loss_val = 0.1012; acc_train = 0.9800; acc_val = 0.9825
# epoch = 35; loss_train = 0.0744; loss_val = 0.0730; acc_train = 0.9900; acc_val = 0.9825
# epoch = 36; loss_train = 0.0894; loss_val = 0.0748; acc_train = 0.9800; acc_val = 0.9812
# epoch = 37; loss_train = 0.1049; loss_val = 0.0766; acc_train = 0.9500; acc_val = 0.9812
# epoch = 38; loss_train = 0.0851; loss_val = 0.0874; acc_train = 0.9700; acc_val = 0.9812
# epoch = 39; loss_train = 0.0733; loss_val = 0.0630; acc_train = 0.9700; acc_val = 0.9812
# epoch = 40; loss_train = 0.0777; loss_val = 0.1058; acc_train = 0.9800; acc_val = 0.9812
# epoch = 41; loss_train = 0.0807; loss_val = 0.0763; acc_train = 0.9700; acc_val = 0.9812
# epoch = 42; loss_train = 0.0731; loss_val = 0.0644; acc_train = 0.9800; acc_val = 0.9812
# epoch = 43; loss_train = 0.0732; loss_val = 0.0690; acc_train = 0.9900; acc_val = 0.9800
# epoch = 44; loss_train = 0.0477; loss_val = 0.0753; acc_train = 0.9900; acc_val = 0.9800
# epoch = 45; loss_train = 0.1131; loss_val = 0.0997; acc_train = 0.9600; acc_val = 0.9800
# epoch = 46; loss_train = 0.1014; loss_val = 0.0862; acc_train = 0.9700; acc_val = 0.9800
# epoch = 47; loss_train = 0.0640; loss_val = 0.0827; acc_train = 1.0000; acc_val = 0.9800
# epoch = 48; loss_train = 0.0978; loss_val = 0.0663; acc_train = 0.9700; acc_val = 0.9800
# epoch = 49; loss_train = 0.0786; loss_val = 0.0492; acc_train = 0.9900; acc_val = 0.9812
# epoch = 50; loss_train = 0.0859; loss_val = 0.0418; acc_train = 0.9800; acc_val = 0.9812
# epoch = 51; loss_train = 0.0613; loss_val = 0.0606; acc_train = 0.9900; acc_val = 0.9812
# epoch = 52; loss_train = 0.0909; loss_val = 0.0808; acc_train = 0.9600; acc_val = 0.9812
# epoch = 53; loss_train = 0.1014; loss_val = 0.0426; acc_train = 0.9600; acc_val = 0.9812
# epoch = 54; loss_train = 0.0655; loss_val = 0.0346; acc_train = 0.9900; acc_val = 0.9812
# epoch = 55; loss_train = 0.0773; loss_val = 0.0545; acc_train = 0.9800; acc_val = 0.9812
# epoch = 56; loss_train = 0.1210; loss_val = 0.0969; acc_train = 0.9600; acc_val = 0.9812
# epoch = 57; loss_train = 0.1146; loss_val = 0.0631; acc_train = 0.9500; acc_val = 0.9812
# epoch = 58; loss_train = 0.0805; loss_val = 0.0672; acc_train = 0.9800; acc_val = 0.9812
# epoch = 59; loss_train = 0.0765; loss_val = 0.0510; acc_train = 0.9800; acc_val = 0.9812
# epoch = 60; loss_train = 0.0606; loss_val = 0.0902; acc_train = 1.0000; acc_val = 0.9812
# epoch = 61; loss_train = 0.0620; loss_val = 0.0793; acc_train = 1.0000; acc_val = 0.9825
# epoch = 62; loss_train = 0.0628; loss_val = 0.0656; acc_train = 0.9900; acc_val = 0.9825
# epoch = 63; loss_train = 0.0570; loss_val = 0.0470; acc_train = 0.9900; acc_val = 0.9825
# epoch = 64; loss_train = 0.0418; loss_val = 0.0347; acc_train = 0.9900; acc_val = 0.9825
# epoch = 65; loss_train = 0.0916; loss_val = 0.0433; acc_train = 0.9600; acc_val = 0.9825
# epoch = 66; loss_train = 0.0826; loss_val = 0.0761; acc_train = 0.9700; acc_val = 0.9825
# epoch = 67; loss_train = 0.0769; loss_val = 0.0324; acc_train = 0.9800; acc_val = 0.9825
# epoch = 68; loss_train = 0.0696; loss_val = 0.1046; acc_train = 0.9600; acc_val = 0.9825
# epoch = 69; loss_train = 0.0812; loss_val = 0.0501; acc_train = 0.9800; acc_val = 0.9825
# epoch = 70; loss_train = 0.0880; loss_val = 0.0607; acc_train = 0.9600; acc_val = 0.9825
# epoch = 71; loss_train = 0.0651; loss_val = 0.0371; acc_train = 0.9800; acc_val = 0.9825
# epoch = 72; loss_train = 0.1055; loss_val = 0.0533; acc_train = 0.9400; acc_val = 0.9825
# epoch = 73; loss_train = 0.0890; loss_val = 0.0821; acc_train = 0.9800; acc_val = 0.9825
# epoch = 74; loss_train = 0.0793; loss_val = 0.0434; acc_train = 0.9900; acc_val = 0.9825
# epoch = 75; loss_train = 0.0406; loss_val = 0.0446; acc_train = 0.9900; acc_val = 0.9825
# epoch = 76; loss_train = 0.0355; loss_val = 0.0639; acc_train = 1.0000; acc_val = 0.9825
# epoch = 77; loss_train = 0.0733; loss_val = 0.0469; acc_train = 0.9600; acc_val = 0.9825
# epoch = 78; loss_train = 0.0578; loss_val = 0.0464; acc_train = 0.9800; acc_val = 0.9825
# epoch = 79; loss_train = 0.0636; loss_val = 0.0764; acc_train = 0.9900; acc_val = 0.9825
# epoch = 80; loss_train = 0.0618; loss_val = 0.0621; acc_train = 0.9900; acc_val = 0.9825
# epoch = 81; loss_train = 0.0599; loss_val = 0.0502; acc_train = 0.9900; acc_val = 0.9825
# epoch = 82; loss_train = 0.0741; loss_val = 0.0773; acc_train = 0.9700; acc_val = 0.9825
# epoch = 83; loss_train = 0.0720; loss_val = 0.0770; acc_train = 0.9700; acc_val = 0.9825
# epoch = 84; loss_train = 0.0475; loss_val = 0.0466; acc_train = 0.9900; acc_val = 0.9825
# epoch = 85; loss_train = 0.1257; loss_val = 0.0695; acc_train = 0.9600; acc_val = 0.9825
# epoch = 86; loss_train = 0.0658; loss_val = 0.0313; acc_train = 0.9700; acc_val = 0.9825
# epoch = 87; loss_train = 0.0771; loss_val = 0.0301; acc_train = 0.9800; acc_val = 0.9825
# epoch = 88; loss_train = 0.0466; loss_val = 0.0643; acc_train = 0.9900; acc_val = 0.9825
# epoch = 89; loss_train = 0.0569; loss_val = 0.0634; acc_train = 1.0000; acc_val = 0.9825
# epoch = 90; loss_train = 0.0694; loss_val = 0.0341; acc_train = 0.9600; acc_val = 0.9825
# epoch = 91; loss_train = 0.0487; loss_val = 0.0377; acc_train = 0.9900; acc_val = 0.9825
# epoch = 92; loss_train = 0.0604; loss_val = 0.0370; acc_train = 0.9800; acc_val = 0.9825
# epoch = 93; loss_train = 0.0925; loss_val = 0.0574; acc_train = 0.9600; acc_val = 0.9825
# epoch = 94; loss_train = 0.0485; loss_val = 0.0397; acc_train = 0.9900; acc_val = 0.9825
# epoch = 95; loss_train = 0.0464; loss_val = 0.0810; acc_train = 1.0000; acc_val = 0.9825
# epoch = 96; loss_train = 0.0799; loss_val = 0.0664; acc_train = 0.9800; acc_val = 0.9825
# epoch = 97; loss_train = 0.0466; loss_val = 0.0708; acc_train = 0.9800; acc_val = 0.9825
# epoch = 98; loss_train = 0.0945; loss_val = 0.0374; acc_train = 0.9700; acc_val = 0.9825
# epoch = 99; loss_train = 0.0610; loss_val = 0.0810; acc_train = 0.9800; acc_val = 0.9825

# %% [markdown]
# ### Editing ResNet's last layer

# %%
# change last layer
resnet18.fc = model.fc

# %% [markdown]
# ### Calculating accuracy of whole network

# %%
# validation
resnet18.eval()
zero_one_loss_val = 0.
for b_ival, (b_xval, b_yval) in enumerate(dl_val):
    y_logitos = resnet18(b_xval)
    yval_sm = torch.nn.functional.softmax(y_logitos, dim=1)
    yval_pred = torch.argmax(yval_sm, dim=1)
    zero_one_loss_val += (b_yval != yval_pred).sum()
    print(b_ival, zero_one_loss_val.data)
# Out:
# 0 tensor(0.)
# 1 tensor(0.)
# 2 tensor(0.)
# 3 tensor(0.)
# 4 tensor(1.)
# 5 tensor(1.)
# 6 tensor(1.)
# 7 tensor(1.)
# 8 tensor(1.)
# 9 tensor(1.)
# 10 tensor(1.)
# 11 tensor(1.)
# 12 tensor(1.)
# 13 tensor(1.)
# 14 tensor(1.)
# 15 tensor(1.)
# 16 tensor(1.)
# 17 tensor(1.)
# 18 tensor(2.)
# 19 tensor(3.)
# 20 tensor(3.)
# 21 tensor(3.)
# 22 tensor(3.)
# 23 tensor(3.)
# 24 tensor(3.)
# 25 tensor(3.)
# 26 tensor(4.)
# 27 tensor(5.)
# 28 tensor(5.)
# 29 tensor(5.)
# 30 tensor(6.)
# 31 tensor(6.)
# 32 tensor(6.)
# 33 tensor(6.)
# 34 tensor(6.)
# 35 tensor(6.)
# 36 tensor(7.)
# 37 tensor(7.)
# 38 tensor(7.)
# 39 tensor(7.)
# 40 tensor(7.)
# 41 tensor(7.)
# 42 tensor(8.)
# 43 tensor(8.)
# 44 tensor(8.)
# 45 tensor(8.)
# 46 tensor(9.)
# 47 tensor(9.)
# 48 tensor(9.)
# 49 tensor(10.)
# 50 tensor(10.)
# 51 tensor(10.)
# 52 tensor(10.)
# 53 tensor(10.)
# 54 tensor(10.)
# 55 tensor(10.)
# 56 tensor(11.)
# 57 tensor(12.)
# 58 tensor(12.)
# 59 tensor(12.)
# 60 tensor(12.)
# 61 tensor(12.)
# 62 tensor(12.)
# 63 tensor(12.)
# 64 tensor(12.)
# 65 tensor(13.)
# 66 tensor(13.)
# 67 tensor(14.)
# 68 tensor(14.)
# 69 tensor(14.)
# 70 tensor(14.)
# 71 tensor(14.)
# 72 tensor(14.)
# 73 tensor(14.)
# 74 tensor(14.)
# 75 tensor(14.)
# 76 tensor(14.)
# 77 tensor(14.)
# 78 tensor(14.)
# 79 tensor(14.)

# %%
zol = zero_one_loss_val / len(dataset_valid)
acc = 1 - zol
print('zero-one loss = {0:.4f}'.format(zol))
print('accuracy = {0:.4f}'.format(acc))
# Out:
# zero-one loss = 0.0175
# accuracy = 0.9825

# %% [markdown]
# with the normalization, the accuracy was 0.9638

# %% [markdown]
# Fazer classificador cats and dogs usando transfer learning:
# - Escolher a rede: minha sugestão resnet18 ou resnet34
#  **rede escolhida: resnet18**
#
# - Escolher o ponto de corte da rede, estimar o tamanho do arquivo das features
#  **ponto de corte: última camada (fc)**
#  **tamanho do arquivo das features:**
#  **entrada resnet: 3 * 224 * 224 * 2000 = 301 MB**
#  **saida resnet: 512 * 512 * 2000 = 524 MB**
# - Fazer o predict das features, no conjunto de treinamento e no conjunto de validação
#  **feito na etapa "Network predict"**
# - Fazer o treinamento, com validação da(s) camada(s) final (ais) da rede de classificação cats/dogs.
#  **feito na etapa "Training only last layer"**
# - Colocar os pesos treinados nas camadas finais na rede resnet modificada
#  **feito na etapa "Editing ResNet's last layer"**
# - Fazer a avaliação da acurácia usando a rede resnet modificada no conjunto de validação: Acurácia
#  **feito na etapa "Calculating accuracy of whole network"**
